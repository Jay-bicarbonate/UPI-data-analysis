# %%
import os
import pandas as pd

# Define the folder where the CSV files are located
folder_path = "D:/dataset/UPI/applications"  # Replace with your folder path

# %%
# Initialize an empty list to store DataFrames
dataframes = []

# Iterate through all files in the folder
for file_name in sorted(os.listdir(folder_path)):
    if file_name.endswith(".csv"):
        file_path = os.path.join(folder_path, file_name)
        # Read the CSV file into a DataFrame
        df = pd.read_csv(file_path)

        # Extract year and month from the file name
        year = 2000 + int(file_name[-6:-4])  # Extract year from file name
        month = {
            'jan': 1, 'feb': 2, 'mar': 3, 'apr': 4, 'may': 5, 'jun': 6,
            'jul': 7, 'aug': 8, 'sep': 9, 'oct': 10, 'nov': 11, 'dec': 12
        }.get(file_name[:3].lower(), 0)  # Extract month from file name

        # Add year and month columns to the DataFrame
        df['Year'] = year
        df['Month'] = month

        # Append the DataFrame to the list
        dataframes.append(df)

# %%
# Combine all DataFrames into a single DataFrame
combined_df = pd.concat(dataframes, ignore_index=True)

combined_df.head()
# Out:
#    Sr.No.            Application Name  Volume Customer(Mn)  \
# 0       1   Airtel Payments Bank Apps                 5.29
# 1       2                  Amazon Pay                73.21
# 2       3  AU Small Finance Bank Apps                 0.32
# 3       4              Axis Bank Apps                 7.19
# 4       5               Bajaj Finserv                 0.52
#
#    Value Customer (Cr) Volume B2C (Mn) Value B2C (Cr) Volume B2B(Mn)  \
# 0               454.64               -              -              -
# 1              6699.57               -              -              -
# 2               109.89               -              -              -
# 3              1213.44           56.84          43.71              0
# 4                38.61               -              -              -
#
#   Value B2B(Cr)  Volume (Mn)  Value (Cr)  Year  Month
# 0             -         5.30      460.90  2022      4
# 1             -        73.21     6699.57  2022      4
# 2             -         0.32      109.89  2022      4
# 3             0        64.03     1257.15  2022      4
# 4             -         0.52       38.61  2022      4

# %%
# Reorder the columns to place 'Year' and 'Month' as the 3rd and 4th columns
columns = list(combined_df.columns)
columns.insert(2, columns.pop(columns.index('Year')))
columns.insert(3, columns.pop(columns.index('Month')))
combined_df = combined_df[columns]

combined_df.head()
# Out:
#    Sr.No.            Application Name  Year  Month  Volume Customer(Mn)  \
# 0       1   Airtel Payments Bank Apps  2022      4                 5.29
# 1       2                  Amazon Pay  2022      4                73.21
# 2       3  AU Small Finance Bank Apps  2022      4                 0.32
# 3       4              Axis Bank Apps  2022      4                 7.19
# 4       5               Bajaj Finserv  2022      4                 0.52
#
#    Value Customer (Cr) Volume B2C (Mn) Value B2C (Cr) Volume B2B(Mn)  \
# 0               454.64               -              -              -
# 1              6699.57               -              -              -
# 2               109.89               -              -              -
# 3              1213.44           56.84          43.71              0
# 4                38.61               -              -              -
#
#   Value B2B(Cr)  Volume (Mn)  Value (Cr)
# 0             -         5.30      460.90
# 1             -        73.21     6699.57
# 2             -         0.32      109.89
# 3             0        64.03     1257.15
# 4             -         0.52       38.61

# %%
# Define the columns to check for numeric values
numeric_columns = [
    "Volume Customer(Mn)", "Value Customer (Cr)", "Volume B2C (Mn)",
    "Value B2C (Cr)", "Volume B2B(Mn)", "Value B2B(Cr)",
    "Volume (Mn)", "Value (Cr)"
]

# Remove commas and convert to numeric, forcing invalid entries to NaN
for col in numeric_columns:
    combined_df[col] = pd.to_numeric(combined_df[col].replace({',': ''}, regex=True), errors='coerce')

# Check for any invalid (NaN) values
invalid_entries = combined_df[numeric_columns].isna().sum()
print("Invalid entries in each column:\n", invalid_entries)
# Out:
# Invalid entries in each column:
#  Volume Customer(Mn)      0
# Value Customer (Cr)      0
# Volume B2C (Mn)        952
# Value B2C (Cr)         953
# Volume B2B(Mn)         836
# Value B2B(Cr)          834
# Volume (Mn)              0
# Value (Cr)               0
# dtype: int64

# %%
combined_df.head()
# Out:
#    Sr.No.            Application Name  Year  Month  Volume Customer(Mn)  \
# 0       1   Airtel Payments Bank Apps  2022      4                 5.29
# 1       2                  Amazon Pay  2022      4                73.21
# 2       3  AU Small Finance Bank Apps  2022      4                 0.32
# 3       4              Axis Bank Apps  2022      4                 7.19
# 4       5               Bajaj Finserv  2022      4                 0.52
#
#    Value Customer (Cr)  Volume B2C (Mn)  Value B2C (Cr)  Volume B2B(Mn)  \
# 0               454.64              NaN             NaN             NaN
# 1              6699.57              NaN             NaN             NaN
# 2               109.89              NaN             NaN             NaN
# 3              1213.44            56.84           43.71             0.0
# 4                38.61              NaN             NaN             NaN
#
#    Value B2B(Cr)  Volume (Mn)  Value (Cr)
# 0            NaN         5.30      460.90
# 1            NaN        73.21     6699.57
# 2            NaN         0.32      109.89
# 3            0.0        64.03     1257.15
# 4            NaN         0.52       38.61

# %%
# Get all unique names in the 'Application Name' column
unique_applications = combined_df['Application Name'].unique()
unique_applications.sort()

for i in unique_applications:
    print(i)
# Out:
# AU Small Finance Bank App
# AU Small Finance Bank Apps
# Aditya Birla Capital Digital
# Aditya Birla Capital Digital #
# Aditya Birla Capital Digital Limited
# Airtel Payments Bank Apps
# Akudo & Muvin (Livquik)
# Allahabad Bank App
# Allahabad Bank Apps
# Amazon Pay
# Amazon Pay #
# Andhra Bank Apps
# Au Small Finance Bank Apps
# Axis Bank Apps
# BHIM
# BHIM #
# BPAYWALLET
# Bajaj Finserv
# Bajaj Finserv #
# Bajaj Finserv PPI
# Bajaj Markets
# Bajaj Pay Wallet
# Bandhan Bank Apps
# Bank of America Apps
# Bank of Baroda Apps
# Bank of India App
# Bank of India Apps
# Bank of Maharashtra App
# Bank of Maharashtra Apps
# Bharat Pe
# Bharat Pe #
# CBDC
# CBDC Apps
# Canara Bank App
# Canara Bank Apps
# Central Bank of India App
# Central Bank of India Apps
# Cheq
# Citi Bank App
# Citi Bank Apps
# City Union Bank App
# City Union Bank Apps
# Cointab
# Cred
# Cred #
# DBS Bank Apps
# DBS Digibank App
# DBS Digibank Apps
# DHANI
# DIGIKHATA
# Dena Bank App
# Dena Bank Apps
# Deutsche Bank App
# Deutsche Bank Apps
# Dhani
# Dhani #
# Dhani PPI
# Dhanlaxmi Bank App
# Dhanlaxmi Bank Apps
# Digikhata
# Digikhata #
# Digikhata PPI
# EROUTE
# ESAF Small Finance Bank Apps
# Equitas Small Apps
# Equitas Small Finance Bank Apps
# Eroute
# FAM
# FIFEDERAL
# Fam App by Trio #
# FamApp by Trio
# FamApp by Trio #
# FamPay PPI
# FamPay by Trio #
# Fampay
# Fampay PPI
# Fampay by Trio #
# Fave
# Fave #
# Federal Bank App
# Federal Bank Apps
# Fi Money #
# Fino Payments Bank Apps
# Fino Payments bank App
# Fino Payments bank Apps
# Finserv Markets
# Finshell Pay
# Flipkart
# Flipkart UPI
# Flipkart UPI #
# Freecharge #
# Freo #
# Freo Money #
# GOAXB
# Genwise #
# Go Kiwi
# Go Niyo
# GoIbibo
# GoKiwi
# GoNiyo PPI
# Gokiwi
# Google Pay
# Google Pay #
# Groww
# Groww #
# HDFC Bank Apps
# HSBC Bank App
# HSBC Bank Apps
# ICICI Bank Apps
# IDBI Bank App
# IDBI Bank Apps
# IDFC Bank App
# IDFC Bank Apps
# IDFC First Bank Apps
# INDIE
# INDIE - Indus Ind
# India Post Payments Bank App
# India Post Payments Bank Apps
# Indian Bank App
# Indian Bank Apps
# Indian Overseas Bank Apps
# IndusInd Bank App
# IndusInd Bank Apps
# Jammu and Kashmir Bank App
# Jammu and Kashmir Bank Apps
# Janata Sahakari Bank Apps
# Janta Sahakari Bank App
# Jio Payments Bank App
# Jio Payments Bank Apps
# Jupiter
# Jupiter Edge
# Jupiter Edge (LivQuick PPI App)
# Jupiter Edge (LivQuick PPI)
# Jupiter Money
# Jupiter Money #
# KIWI
# Karnataka Bank App
# Karnataka Bank Apps
# Karur Vysya Bank App
# Karur Vysya Bank Apps
# Kiwi
# Kiwi #
# Kotak Mahindra Bank Apps
# Kredit.Pe #
# LivQuick PPI
# LivQuik Apps #
# MBK
# MI Pay
# MakeMy Trip
# MakeMyTrip
# Mobikwik
# Mobikwik #
# Mobikwik PPI
# Money View #
# NAVIAXIS
# NSDL Payments Bank App
# NSDL Payments Bank Apps
# Navi
# Navi #
# Niyo Global
# Niyo Global #
# OMNI
# Omni Card
# OmniCard
# OmniCard #
# Omnicard
# Omnicard #
# Omnicard PPI
# One Card #
# Other
# Other Apps
# Others
# PAYTMWALLET
# PINELABS
# POPClub #
# POPClub#
# Paytm
# Paytm #
# Paytm (OCL ) #
# Paytm (OCL)
# Paytm (OCL) #
# Paytm Payments Bank App
# PhonePe
# PhonePe #
# Phonepe #
# Pop Club
# Pop Club #
# Punjab And Sind Bank Apps
# Punjab National Bank App
# Punjab National Bank Apps
# Punjab Sind Bank Apps
# Punjab Sindh Bank App
# Punjab Sindh Bank Apps
# RBL Bank App
# RBL Bank Apps
# RBLBANK
# Rapi Pay
# Rapi Pay #
# Rapipay
# SBI Bank Apps
# SHRIRAM
# SLICE
# SURYODAY
# Salary Se #
# Samsung Pay
# Samsung Pay #
# Shri Ram One #
# Shriram
# Shriram One
# Shriram One #
# Slash
# Slice
# Slice #
# South Indian Bank App
# South Indian Bank Apps
# Spice Money
# Standard Chartered Bank App
# Standard Chartered Bank Apps
# State Bank of India Apps
# SuperPay
# Suryoday
# Suryoday Bank Apps
# TJSB Bank Apps
# Tamilnad Mercantile Bank Apps
# Tata Neu #
# TataNeu
# TataNeu #
# Timepay
# Timepay #
# Transerv
# Transerv PPI
# True Balance
# UCO Bank App
# UCO Bank Apps
# Ultracash
# Ultracash #
# Union Bank Apps
# Union Bank Of India Apps
# Utkarsh Small Finance Bank
# Utkarsh Small Finance Bank Apps
# WhatsApp
# WhatsApp #
# Whatsapp #
# Yes Bank Apps
# YuvaPay
# ZOICICI
# Zomato
# slice
# slice #
# slice PPI
# super.money #

# %%
app_names = [
[["AU Small Finance Bank App"],["AU Small Finance Bank Apps","Au Small Finance Bank Apps"]],
[["Aditya Birla Capital Digital"],["Aditya Birla Capital Digital #","Aditya Birla Capital Digital Limited"]],
[["Allahabad Bank App"],["Allahabad Bank Apps"]],
[["Amazon Pay"],["Amazon Pay #"]],
[["BHIM"],["BHIM #"]],
[["Bajaj Finserv"],["Bajaj Finserv #","Bajaj Finserv PPI","Bajaj Markets","Bajaj Pay Wallet"]],
[["Bank of India App"],["Bank of India Apps"]],
[["Bank of Maharashtra App"],["Bank of Maharashtra Apps"]],
[["Bharat Pe"],["Bharat Pe #"]],
[["CBDC"],["CBDC Apps"]],
[["Canara Bank App"],["Canara Bank Apps"]],
[["Central Bank of India App"],["Central Bank of India Apps"]],
[["Citi Bank App"],["Citi Bank Apps"]],
[["City Union Bank App"],["City Union Bank Apps"]],
[["Cred"],["Cred #"]],
[["DBS Bank Apps"],["DBS Digibank App","DBS Digibank Apps"]],
[["Dena Bank App"],["Dena Bank Apps"]],
[["Deutsche Bank App"],["Deutsche Bank Apps"]],
[["Dhani"],["Dhani #","Dhani PPI","DHANI"]],
[["Dhanlaxmi Bank App"],["Dhanlaxmi Bank Apps"]],
[["Digikhata"],["Digikhata #","Digikhata PPI","DIGIKHATA"]],
[["Equitas Small Apps"],["Equitas Small Finance Bank Apps"]],
[["EROUTE"],["Eroute"]],
[["FamApp by Trio"],["Fam App by Trio #","FamApp by Trio #","Fampay","FamPay PPI","FamPay by Trio #","Fampay PPI","Fampay by Trio #"]],
[["Fave"],["Fave #"]],
[["Federal Bank App"],["Federal Bank Apps"]],
[["Fino Payments Bank App"],["Fino Payments Bank Apps","Fino Payments bank Apps","Fino Payments bank App"]],
[["Flipkart UPI"],["Flipkart","Flipkart UPI #"]],
[["Freo #"],["Freo Money #"]],
[["GoKiwi"],["Go Kiwi","KIWI","Kiwi","Kiwi #","Gokiwi"]],
[["GoNiyo"],["Go Niyo","GoNiyo PPI"]],
[["Google Pay"],["Google Pay #"]],
[["Groww"],["Groww #"]],
[["HSBC Bank App"],["HSBC Bank Apps"]],
[["IDBI Bank App"],["IDBI Bank Apps"]],
[["IDFC First Bank Apps"],["IDFC Bank App","IDFC Bank Apps"]],
[["INDIE"],["INDIE - Indus Ind","IndusInd Bank App","IndusInd Bank Apps"]],
[["India Post Payments Bank App"],["India Post Payments Bank Apps"]],
[["Indian Bank App"],["Indian Bank Apps"]],
[["Jammu and Kashmir Bank App"],["Jammu and Kashmir Bank Apps"]],
[["Janta Sahakari Bank App"],["Janata Sahakari Bank Apps"]],
[["Jio Payments Bank App"],["Jio Payments Bank Apps"]],
[["Jupiter Money"],["Jupiter","Jupiter Edge (LivQuick PPI App)","Jupiter Edge (LivQuick PPI)","Jupiter Money #","Jupiter Edge"]],
[["Karnataka Bank App"],["Karnataka Bank Apps"]],
[["Karur Vysya Bank App"],["Karur Vysya Bank Apps"]],
[["LivQuick PPI"],["LivQuik Apps #"]],
[["MakeMyTrip"],["MakeMy Trip"]],
[["Mobikwik"],["Mobikwik #","Mobikwik PPI"]],
[["NSDL Payments Bank App"],["NSDL Payments Bank Apps"]],
[["Navi"],["Navi #"]],
[["Niyo Global"],["Niyo Global #"]],
[["OMNI"],["Omni Card","OmniCard","OmniCard #","Omnicard","Omnicard #","Omnicard PPI"]],
[["Others"],["Other Apps","Other"]],
[["POPClub #"],["POPClub#"]],
[["Paytm"],["Paytm #","PAYTMWALLET","Paytm (OCL ) #","Paytm (OCL)","Paytm (OCL) #","Paytm Payments Bank App"]],
[["PhonePe"],["PhonePe #","Phonepe #"]],
[["Pop Club"],["Pop Club #","POPClub #"]],
[["Punjab National Bank App"],["Punjab National Bank Apps"]],
[["Punjab Sindh Bank App"],["Punjab Sind Bank Apps","Punjab And Sind Bank Apps","Punjab Sindh Bank Apps"]],
[["RBL Bank App"],["RBL Bank Apps","RBLBANK"]],
[["Rapipay"],["Rapi Pay #","Rapi Pay"]],
[["Samsung Pay"],["Samsung Pay #"]],
[["Shriram One"],["SHRIRAM","Shri Ram One #","Shriram","Shriram One #"]],
[["Slice"],["Slice","slice","slice #","slice PPI","Slice #","SLICE"]],
[["South Indian Bank App"],["South Indian Bank Apps"]],
[["Standard Chartered Bank App"],["Standard Chartered Bank Apps"]],
[["SBI Bank Apps"],["State Bank of India Apps"]],
[["Suryoday"],["Suryoday Bank Apps","SURYODAY"]],
[["TataNeu"],["Tata Neu #","TataNeu #"]],
[["Timepay"],["Timepay #"]],
[["Transerv"],["Transerv PPI"]],
[["UCO Bank App"],["UCO Bank Apps"]],
[["Ultracash"],["Ultracash #"]],
[["Union Bank Apps"],["Union Bank Of India Apps"]],
[["Utkarsh Small Finance Bank"],["Utkarsh Small Finance Bank Apps"]],
[["WhatsApp"],["WhatsApp #","Whatsapp #"]],
]

len(app_names)
# Out:
# 76

# %%
for app in app_names:
    new_name = app[0][0]
    for replace in app[1]:
        old_name = replace
        combined_df['Application Name'] = combined_df['Application Name'].replace(old_name, new_name)
        print(f"Replaced '{old_name}' with '{new_name}'")
# Out:
# Replaced 'AU Small Finance Bank Apps' with 'AU Small Finance Bank App'
# Replaced 'Au Small Finance Bank Apps' with 'AU Small Finance Bank App'
# Replaced 'Aditya Birla Capital Digital #' with 'Aditya Birla Capital Digital'
# Replaced 'Aditya Birla Capital Digital Limited' with 'Aditya Birla Capital Digital'
# Replaced 'Allahabad Bank Apps' with 'Allahabad Bank App'
# Replaced 'Amazon Pay #' with 'Amazon Pay'
# Replaced 'BHIM #' with 'BHIM'
# Replaced 'Bajaj Finserv #' with 'Bajaj Finserv'
# Replaced 'Bajaj Finserv PPI' with 'Bajaj Finserv'
# Replaced 'Bajaj Markets' with 'Bajaj Finserv'
# Replaced 'Bajaj Pay Wallet' with 'Bajaj Finserv'
# Replaced 'Bank of India Apps' with 'Bank of India App'
# Replaced 'Bank of Maharashtra Apps' with 'Bank of Maharashtra App'
# Replaced 'Bharat Pe #' with 'Bharat Pe'
# Replaced 'CBDC Apps' with 'CBDC'
# Replaced 'Canara Bank Apps' with 'Canara Bank App'
# Replaced 'Central Bank of India Apps' with 'Central Bank of India App'
# Replaced 'Citi Bank Apps' with 'Citi Bank App'
# Replaced 'City Union Bank Apps' with 'City Union Bank App'
# Replaced 'Cred #' with 'Cred'
# Replaced 'DBS Digibank App' with 'DBS Bank Apps'
# Replaced 'DBS Digibank Apps' with 'DBS Bank Apps'
# Replaced 'Dena Bank Apps' with 'Dena Bank App'
# Replaced 'Deutsche Bank Apps' with 'Deutsche Bank App'
# Replaced 'Dhani #' with 'Dhani'
# Replaced 'Dhani PPI' with 'Dhani'
# Replaced 'DHANI' with 'Dhani'
# Replaced 'Dhanlaxmi Bank Apps' with 'Dhanlaxmi Bank App'
# Replaced 'Digikhata #' with 'Digikhata'
# Replaced 'Digikhata PPI' with 'Digikhata'
# Replaced 'DIGIKHATA' with 'Digikhata'
# Replaced 'Equitas Small Finance Bank Apps' with 'Equitas Small Apps'
# Replaced 'Eroute' with 'EROUTE'
# Replaced 'Fam App by Trio #' with 'FamApp by Trio'
# Replaced 'FamApp by Trio #' with 'FamApp by Trio'
# Replaced 'Fampay' with 'FamApp by Trio'
# Replaced 'FamPay PPI' with 'FamApp by Trio'
# Replaced 'FamPay by Trio #' with 'FamApp by Trio'
# Replaced 'Fampay PPI' with 'FamApp by Trio'
# Replaced 'Fampay by Trio #' with 'FamApp by Trio'
# Replaced 'Fave #' with 'Fave'
# Replaced 'Federal Bank Apps' with 'Federal Bank App'
# Replaced 'Fino Payments Bank Apps' with 'Fino Payments Bank App'
# Replaced 'Fino Payments bank Apps' with 'Fino Payments Bank App'
# Replaced 'Fino Payments bank App' with 'Fino Payments Bank App'
# Replaced 'Flipkart' with 'Flipkart UPI'
# Replaced 'Flipkart UPI #' with 'Flipkart UPI'
# Replaced 'Freo Money #' with 'Freo #'
# Replaced 'Go Kiwi' with 'GoKiwi'
# Replaced 'KIWI' with 'GoKiwi'
# Replaced 'Kiwi' with 'GoKiwi'
# Replaced 'Kiwi #' with 'GoKiwi'
# Replaced 'Gokiwi' with 'GoKiwi'
# Replaced 'Go Niyo' with 'GoNiyo'
# Replaced 'GoNiyo PPI' with 'GoNiyo'
# Replaced 'Google Pay #' with 'Google Pay'
# Replaced 'Groww #' with 'Groww'
# Replaced 'HSBC Bank Apps' with 'HSBC Bank App'
# Replaced 'IDBI Bank Apps' with 'IDBI Bank App'
# Replaced 'IDFC Bank App' with 'IDFC First Bank Apps'
# Replaced 'IDFC Bank Apps' with 'IDFC First Bank Apps'
# Replaced 'INDIE - Indus Ind' with 'INDIE'
# Replaced 'IndusInd Bank App' with 'INDIE'
# Replaced 'IndusInd Bank Apps' with 'INDIE'
# Replaced 'India Post Payments Bank Apps' with 'India Post Payments Bank App'
# Replaced 'Indian Bank Apps' with 'Indian Bank App'
# Replaced 'Jammu and Kashmir Bank Apps' with 'Jammu and Kashmir Bank App'
# Replaced 'Janata Sahakari Bank Apps' with 'Janta Sahakari Bank App'
# Replaced 'Jio Payments Bank Apps' with 'Jio Payments Bank App'
# Replaced 'Jupiter' with 'Jupiter Money'
# Replaced 'Jupiter Edge (LivQuick PPI App)' with 'Jupiter Money'
# Replaced 'Jupiter Edge (LivQuick PPI)' with 'Jupiter Money'
# Replaced 'Jupiter Money #' with 'Jupiter Money'
# Replaced 'Jupiter Edge' with 'Jupiter Money'
# Replaced 'Karnataka Bank Apps' with 'Karnataka Bank App'
# Replaced 'Karur Vysya Bank Apps' with 'Karur Vysya Bank App'
# Replaced 'LivQuik Apps #' with 'LivQuick PPI'
# Replaced 'MakeMy Trip' with 'MakeMyTrip'
# Replaced 'Mobikwik #' with 'Mobikwik'
# Replaced 'Mobikwik PPI' with 'Mobikwik'
# Replaced 'NSDL Payments Bank Apps' with 'NSDL Payments Bank App'
# Replaced 'Navi #' with 'Navi'
# Replaced 'Niyo Global #' with 'Niyo Global'
# Replaced 'Omni Card' with 'OMNI'
# Replaced 'OmniCard' with 'OMNI'
# Replaced 'OmniCard #' with 'OMNI'
# Replaced 'Omnicard' with 'OMNI'
# Replaced 'Omnicard #' with 'OMNI'
# Replaced 'Omnicard PPI' with 'OMNI'
# Replaced 'Other Apps' with 'Others'
# Replaced 'Other' with 'Others'
# Replaced 'POPClub#' with 'POPClub #'
# Replaced 'Paytm #' with 'Paytm'
# Replaced 'PAYTMWALLET' with 'Paytm'
# Replaced 'Paytm (OCL ) #' with 'Paytm'
# Replaced 'Paytm (OCL)' with 'Paytm'
# Replaced 'Paytm (OCL) #' with 'Paytm'
# Replaced 'Paytm Payments Bank App' with 'Paytm'
# Replaced 'PhonePe #' with 'PhonePe'
# Replaced 'Phonepe #' with 'PhonePe'
# Replaced 'Pop Club #' with 'Pop Club'
# Replaced 'POPClub #' with 'Pop Club'
# Replaced 'Punjab National Bank Apps' with 'Punjab National Bank App'
# Replaced 'Punjab Sind Bank Apps' with 'Punjab Sindh Bank App'
# Replaced 'Punjab And Sind Bank Apps' with 'Punjab Sindh Bank App'
# Replaced 'Punjab Sindh Bank Apps' with 'Punjab Sindh Bank App'
# Replaced 'RBL Bank Apps' with 'RBL Bank App'
# Replaced 'RBLBANK' with 'RBL Bank App'
# Replaced 'Rapi Pay #' with 'Rapipay'
# Replaced 'Rapi Pay' with 'Rapipay'
# Replaced 'Samsung Pay #' with 'Samsung Pay'
# Replaced 'SHRIRAM' with 'Shriram One'
# Replaced 'Shri Ram One #' with 'Shriram One'
# Replaced 'Shriram' with 'Shriram One'
# Replaced 'Shriram One #' with 'Shriram One'
# Replaced 'Slice' with 'Slice'
# Replaced 'slice' with 'Slice'
# Replaced 'slice #' with 'Slice'
# Replaced 'slice PPI' with 'Slice'
# Replaced 'Slice #' with 'Slice'
# Replaced 'SLICE' with 'Slice'
# Replaced 'South Indian Bank Apps' with 'South Indian Bank App'
# Replaced 'Standard Chartered Bank Apps' with 'Standard Chartered Bank App'
# Replaced 'State Bank of India Apps' with 'SBI Bank Apps'
# Replaced 'Suryoday Bank Apps' with 'Suryoday'
# Replaced 'SURYODAY' with 'Suryoday'
# Replaced 'Tata Neu #' with 'TataNeu'
# Replaced 'TataNeu #' with 'TataNeu'
# Replaced 'Timepay #' with 'Timepay'
# Replaced 'Transerv PPI' with 'Transerv'
# Replaced 'UCO Bank Apps' with 'UCO Bank App'
# Replaced 'Ultracash #' with 'Ultracash'
# Replaced 'Union Bank Of India Apps' with 'Union Bank Apps'
# Replaced 'Utkarsh Small Finance Bank Apps' with 'Utkarsh Small Finance Bank'
# Replaced 'WhatsApp #' with 'WhatsApp'
# Replaced 'Whatsapp #' with 'WhatsApp'

# %%
# Get all unique names in the 'Application Name' column
unique_applications = combined_df['Application Name'].unique()
unique_applications.sort()

for i in unique_applications:
    print(i)
# Out:
# AU Small Finance Bank App
# Aditya Birla Capital Digital
# Airtel Payments Bank Apps
# Akudo & Muvin (Livquik)
# Allahabad Bank App
# Amazon Pay
# Andhra Bank Apps
# Axis Bank Apps
# BHIM
# BPAYWALLET
# Bajaj Finserv
# Bandhan Bank Apps
# Bank of America Apps
# Bank of Baroda Apps
# Bank of India App
# Bank of Maharashtra App
# Bharat Pe
# CBDC
# Canara Bank App
# Central Bank of India App
# Cheq
# Citi Bank App
# City Union Bank App
# Cointab
# Cred
# DBS Bank Apps
# Dena Bank App
# Deutsche Bank App
# Dhani
# Dhanlaxmi Bank App
# Digikhata
# EROUTE
# ESAF Small Finance Bank Apps
# Equitas Small Apps
# FAM
# FIFEDERAL
# FamApp by Trio
# Fave
# Federal Bank App
# Fi Money #
# Fino Payments Bank App
# Finserv Markets
# Finshell Pay
# Flipkart UPI
# Freecharge #
# Freo #
# GOAXB
# Genwise #
# GoIbibo
# GoKiwi
# GoNiyo
# Google Pay
# Groww
# HDFC Bank Apps
# HSBC Bank App
# ICICI Bank Apps
# IDBI Bank App
# IDFC First Bank Apps
# INDIE
# India Post Payments Bank App
# Indian Bank App
# Indian Overseas Bank Apps
# Jammu and Kashmir Bank App
# Janta Sahakari Bank App
# Jio Payments Bank App
# Jupiter Money
# Karnataka Bank App
# Karur Vysya Bank App
# Kotak Mahindra Bank Apps
# Kredit.Pe #
# LivQuick PPI
# MBK
# MI Pay
# MakeMyTrip
# Mobikwik
# Money View #
# NAVIAXIS
# NSDL Payments Bank App
# Navi
# Niyo Global
# OMNI
# One Card #
# Others
# PINELABS
# Paytm
# PhonePe
# Pop Club
# Punjab National Bank App
# Punjab Sindh Bank App
# RBL Bank App
# Rapipay
# SBI Bank Apps
# Salary Se #
# Samsung Pay
# Shriram One
# Slash
# Slice
# South Indian Bank App
# Spice Money
# Standard Chartered Bank App
# SuperPay
# Suryoday
# TJSB Bank Apps
# Tamilnad Mercantile Bank Apps
# TataNeu
# Timepay
# Transerv
# True Balance
# UCO Bank App
# Ultracash
# Union Bank Apps
# Utkarsh Small Finance Bank
# WhatsApp
# Yes Bank Apps
# YuvaPay
# ZOICICI
# Zomato
# super.money #

# %%
combined_df.head()
# Out:
#    Sr.No.           Application Name  Year  Month  Volume Customer(Mn)  \
# 0       1  Airtel Payments Bank Apps  2022      4                 5.29
# 1       2                 Amazon Pay  2022      4                73.21
# 2       3  AU Small Finance Bank App  2022      4                 0.32
# 3       4             Axis Bank Apps  2022      4                 7.19
# 4       5              Bajaj Finserv  2022      4                 0.52
#
#    Value Customer (Cr)  Volume B2C (Mn)  Value B2C (Cr)  Volume B2B(Mn)  \
# 0               454.64              NaN             NaN             NaN
# 1              6699.57              NaN             NaN             NaN
# 2               109.89              NaN             NaN             NaN
# 3              1213.44            56.84           43.71             0.0
# 4                38.61              NaN             NaN             NaN
#
#    Value B2B(Cr)  Volume (Mn)  Value (Cr)
# 0            NaN         5.30      460.90
# 1            NaN        73.21     6699.57
# 2            NaN         0.32      109.89
# 3            0.0        64.03     1257.15
# 4            NaN         0.52       38.61

# %%
# Save the combined DataFrame to a new CSV file
output_file = "D:/dataset/UPI/applications/combined_upi_data.csv"
combined_df.to_csv(output_file, index=False)
# Drop the first column of the DataFrame
combined_df = combined_df.iloc[:, 1:]

print(f"Combined CSV file saved as: {output_file}")
# Out:
# Combined CSV file saved as: D:/dataset/UPI/applications/combined_upi_data.csv
